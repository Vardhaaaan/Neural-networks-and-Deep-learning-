# %% [markdown]
# <a href="https://colab.research.google.com/github/Vardhaaaan/Neural-networks-and-Deep-learning-/blob/main/feed_forward_network_using_class_and_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class FeedForwardNN:
    def __init__(self):
        self.a = np.array([0.6, 0.4, 0.8])
        self.W1 = np.array([[0.2, 0.3],
                            [0.1, 0.4],
                            [0.5, 0.7]])
        self.b1 = np.array([0.7, 0.2])

        self.W2 = np.array([[0.3],
                            [0.5]])
        self.b2 = np.array([0.05])

        self.lr = 0.2

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def forward(self):
        self.z1 = np.dot(self.a, self.W1) + self.b1
        self.a1 = self.sigmoid(self.z1)

        self.z2 = np.dot(self.a1, self.W2) + self.b2
        self.a2 = self.sigmoid(self.z2)

        return self.a2

    def compute_loss(self, target):
        self.loss = (target - self.a2) ** 2
        return self.loss

    def train_step(self, target):
        output = self.forward()
        loss = self.compute_loss(target)
        return output, loss

nn = FeedForwardNN()

target = 1

epochs = 1000

for epoch in range(epochs):
    output, loss = nn.train_step(target)

    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Output={output[0]:.4f}, Loss={loss[0]:.6f}")
# Out:
# Epoch 0: Output=0.6590, Loss=0.116281
# Epoch 100: Output=0.6590, Loss=0.116281
# Epoch 200: Output=0.6590, Loss=0.116281
# Epoch 300: Output=0.6590, Loss=0.116281
# Epoch 400: Output=0.6590, Loss=0.116281
# Epoch 500: Output=0.6590, Loss=0.116281
# Epoch 600: Output=0.6590, Loss=0.116281
# Epoch 700: Output=0.6590, Loss=0.116281
# Epoch 800: Output=0.6590, Loss=0.116281
# Epoch 900: Output=0.6590, Loss=0.116281
