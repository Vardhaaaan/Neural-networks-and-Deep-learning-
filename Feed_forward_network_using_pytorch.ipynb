# %% [markdown]
# <a href="https://colab.research.google.com/github/Vardhaaaan/Neural-networks-and-Deep-learning-/blob/main/Feed_forward_network_using_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
X = torch.tensor([[0.2, 0.3, 0.4]], dtype=torch.float32)

y = torch.tensor([[1.0]], dtype=torch.float32)

# %%
class FeedForwardNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(3, 2)

        self.fc2 = nn.Linear(2, 1)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        z1 = self.fc1(x)
        a1 = self.sigmoid(z1)

        z2 = self.fc2(a1)
        a2 = self.sigmoid(z2)

        return a2

# %%
model = FeedForwardNN()

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
epochs = 1000

for epoch in range(epochs):
    output = model(X)

    loss = criterion(output, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Output={output.item():.4f}, Loss={loss.item():.6f}")
# Out:
# Epoch 0: Output=0.9561, Loss=0.001925
# Epoch 100: Output=0.9585, Loss=0.001721
# Epoch 200: Output=0.9606, Loss=0.001554
# Epoch 300: Output=0.9624, Loss=0.001416
# Epoch 400: Output=0.9639, Loss=0.001300
# Epoch 500: Output=0.9654, Loss=0.001200
# Epoch 600: Output=0.9666, Loss=0.001114
# Epoch 700: Output=0.9678, Loss=0.001039
# Epoch 800: Output=0.9688, Loss=0.000973
# Epoch 900: Output=0.9697, Loss=0.000915
