# %% [markdown]
# <a href="https://colab.research.google.com/github/Vardhaaaan/Neural-networks-and-Deep-learning-/blob/main/Backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# -------- Input layer --------
# Input vector
a = np.array([0.3, 0.5, 0.4])

# Weights from input layer to hidden layer
b = np.array([[0.2, 0.3],
              [0.1, 0.4],
              [0.5, 0.7]])

# Bias for hidden layer
c = np.array([0.7, 0.2])

# -------- Hidden layer --------
# Linear combination (weighted sum + bias)
x = np.dot(a, b) + c
print("Output:", x)

# Sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Activation output of hidden layer
y = sigmoid(x)
print("Activation output:", y)

# -------- Output layer --------
# Weights from hidden layer to output layer
w2 = np.array([[0.3],
               [0.5]])

# Bias for output layer
a1 = np.array([0.05])

# Linear combination at output layer
b2 = np.dot(y, w2) + a1

# Final output using sigmoid activation
a2 = sigmoid(b2)
print("Final output:", a2)

# -------- Loss calculation --------
# Target output
z = 1

# Mean Squared Error (MSE) loss
loss = (z - a2) ** 2
print("Loss:", loss)

# -------- Backpropagation --------
# Learning rate
lr = 0.1

# Derivative of loss w.r.t output
dloss_da2 = -2 * (z - a2)

# Derivative of sigmoid
da2_dz2 = a2 * (1 - a2)

# Derivative of z2 w.r.t weights w2
dz2_dw2 = y

# Gradient of loss w.r.t w2
grad_w2 = dloss_da2 * da2_dz2 * dz2_dw2

# Update weights using gradient descent
w2 = w2 - lr * grad_w2.reshape(2, 1)
print("Updated W2:", w2)
# Out:
# Output: [1.01 0.77]
# Activation output: [0.73302015 0.68352089]
# Final output: [0.64832086]
# Loss: [0.12367822]
# Updated W2: [[0.31175518]
#  [0.51096137]]

# %%
import numpy as np
import tensorflow as tf

# Input data (different values)
X = np.array([[0.6, 0.2, 0.1]], dtype=np.float32)

# Target output (different target)
y = np.array([[0.0]], dtype=np.float32)

# Define a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(
        3,                      # Different number of hidden neurons
        activation='sigmoid',
        input_shape=(3,)
    ),
    tf.keras.layers.Dense(
        1,
        activation='sigmoid'
    )
])

# Compile the model with a different learning rate
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),
    loss='mse'
)

# Train the model for fewer epochs
history = model.fit(
    X,
    y,
    epochs=800,
    verbose=0
)

# Predict output
output = model.predict(X)
print("Final Output:", output)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Final Output: [[0.06769729]]
